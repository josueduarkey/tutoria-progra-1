# %% [markdown]
# ## Bloque 2: Ciclos y Bucles (For y While)

# %% [markdown]
# ### Tarea 1. Registro de Temperaturas
# Crea un programa que solicite al usuario ingresar 7 lecturas de temperatura (una para cada día de la semana).
# Al final, el programa debe mostrar:
#
# 1. El promedio de las temperaturas **(usar un acumulador)**.
# 2. Cuántos días hubo temperaturas bajo cero **(usar un contador)**.

# %%
# cont = 0
# suma = 0
# while(cont < 7):
#     temperatura = int(input(f'{cont} - Dato'))
#     suma += temperatura
    
#     cont += 1
# print(f'El promedio es {suma/7}')

# %% [markdown]
# ### Tarea 2. Control de Inventario
# Un almacén necesita registrar productos hasta que el usuario decida detenerse ingresando la palabra "salir".
# - Por cada producto, se pide el precio.
# - El programa debe mostrar la suma total de la compra al final.

# %%
# total_pagar = 0
# while(True):
#     product = input('Digite el nombre del producto')
#     if product.lower() == 'salir':
#         print('ADIOOS')
#         break
#     precio = float(input('Digite un precio: '))
#     total_pagar = precio + total_pagar
#     print(f'Hola soy la var: {total_pagar}')

# print(total_pagar)

# %% [markdown]
# ### Tarea 3. Generador de Tablas de Multiplicar
# Solicita un número entero positivo al usuario y muestra su tabla de multiplicar del 1 al 12.
# - Debes usar un bloque for y darle un formato limpio (Ej: $5 \times 1 = 5$).

# %% [markdown]
# ### Tarea 4. El Contador Regresivo Inteligente
# Pide un número inicial al usuario. El programa debe realizar una cuenta regresiva hasta 0. Si el número es par, debe imprimirlo; si es impar, debe imprimir la palabra "Salto".

# %% [markdown]
# ### Tarea 5. Validación de PIN (Intento Limitado)
# Simula un cajero automático. Define un PIN secreto (ej: "1234"). El usuario tiene máximo 3 intentos para ingresarlo correctamente usando un bucle while. Si lo logra, muestra "Acceso concedido"; si agota los intentos, muestra "Tarjeta bloqueada".
